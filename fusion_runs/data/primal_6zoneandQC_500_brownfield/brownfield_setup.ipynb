# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# We need to create a folder for each year, 2000 -> 2020, with unique load_data.csv and generator_variability.csv files for each

# %%
years = np.arange(2000, 2021)

# %%
long_data_dir = Path.cwd().joinpath('data')
long_load = pd.read_csv(long_data_dir.joinpath('Load_data.csv'), index_col=0)
long_variability = pd.read_csv(long_data_dir.joinpath('Generators_variability.csv'), index_col=0)

# %%
long_load
# Out:
#          Demand_Segment  Cost_of_Demand_Curtailment_per_MW  \
# Voll
# 50000.0             1.0                                1.0
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# ...                 ...                                ...
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
# NaN                 NaN                                NaN
#
#          Max_Demand_Curtailment  Rep_Periods  Timesteps_per_Rep_Period  \
# Voll
# 50000.0                     1.0          1.0                  175200.0
# NaN                         NaN          NaN                       NaN
# ...

# %%
for year in [2000]:
    # Create
